# %% [markdown]
# <a href="https://colab.research.google.com/github/gitblankhub/2023-DCC/blob/main/%EB%B3%B8%EC%84%A0%EC%B5%9C%EC%A2%85%EC%A0%9C%EC%B6%9C/Mission3_%EC%A0%9C%EC%B6%9C%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 한글 폰트를 위해 실행 후 런타임 다시 할당
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (51.7 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 120874 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# # 구글 드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 필요한 라이브러리 및 모듈 불러오기
import torch
import numpy as np

import os
from tqdm.notebook import tqdm
from warnings import filterwarnings
filterwarnings('ignore')

import torch
from torch import nn, optim
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split
from torch.utils.tensorboard import SummaryWriter
from torchvision import models
from torchvision import transforms as T
from torchvision.datasets import ImageFolder

from torch.backends import cudnn
cudnn.benchmark = True

import torchvision
import torchvision.transforms as transforms
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
from torchvision.transforms import Compose, ToTensor, Normalize

import torch.nn as nn
import torch.optim as optim
import seaborn as sns
import unicodedata

# %%
# GPU 사용 가능여부 확인
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# 현재 선택된 디바이스 출력
print(device)
# Out:
# cuda:0

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp
# Out:
# /content/drive/MyDrive/Colab Notebooks/DataCreatorCamp

# %% [markdown]
# # 데이터 개수 및 분포 확인

# %%
# kfood_health_train 경로 설정
kfood_health_train = './kfood_health_train'

# 이미지 파일 확장자 리스트
image_extensions = ['.jpg', '.jpeg', '.png', '.gif']

# 디렉토리 내의 각 파일에 대해 이미지 파일 개수 확인
for file_name in os.listdir(kfood_health_train):
    file_path = os.path.join(kfood_health_train, file_name)
    if os.path.isdir(file_path):
        image_count = 0
        for entry in os.listdir(file_path):
            entry_path = os.path.join(file_path, entry)
            if os.path.isfile(entry_path) and any(entry.lower().endswith(ext) for ext in image_extensions):
                # 이미지 파일 확장자를 가진 파일을 찾으면 개수를 누적
                image_count += 1
        print(f"파일명: {file_name}, 이미지 개수: {image_count}")
# Out:
# 파일명: 갈비찜, 이미지 개수: 1267
# 파일명: 된장찌개, 이미지 개수: 951
# 파일명: 김치국, 이미지 개수: 1237
# 파일명: 떡국, 이미지 개수: 962
# 파일명: 고등어, 이미지 개수: 1177
# 파일명: 모듬초밥, 이미지 개수: 1160
# 파일명: 돼지갈비찜, 이미지 개수: 891
# 파일명: 낚지볶음, 이미지 개수: 1032
# 파일명: 가리비, 이미지 개수: 831
# 파일명: 배추김치, 이미지 개수: 1040
# 파일명: 오리로스구이, 이미지 개수: 1152
# 파일명: 부대찌개, 이미지 개수: 1551
# 파일명: 순대, 이미지 개수: 864

# %%
# 한글 폰트 설정
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# 이미지 파일 확장자 리스트
image_extensions = ['.jpg', '.jpeg', '.png', '.gif']

def proc_img(filepath):
    labels = [str(filepath[i]).split("/")[-2] for i in range(len(filepath))]  # 이미지 파일 경로로부터 라벨 추출
    filepath = pd.Series(filepath, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')
    df = pd.concat([filepath, labels], axis=1) # 경로와 라벨 concatenate
    df = df.sample(frac=1, random_state=0).reset_index(drop=True) # index 재설정
    return df

# %%
# 이미지 파일 경로 리스트 생성
image_folder = './kfood_health_train'
image_files = [os.path.join(dp, f) for dp, dn, filenames in os.walk(image_folder) for f in filenames if os.path.splitext(f)[1].lower() in image_extensions]

# 데이터프레임 생성
df = proc_img(image_files)

# %%
# 라벨별 카운트 플롯 그리기
plt.subplots(figsize=(20, 10))
sns.countplot(data=df, x='Label')
plt.xticks(rotation=90)  # x 축 라벨을 90도 회전

# 한글 플롯 레이블에 대한 NFC 정규화
ax = plt.gca()
ax.set_xticklabels([unicodedata.normalize('NFC', label.get_text()) for label in ax.get_xticklabels()])
plt.title('kfood_health_train')

plt.show()

# %%
# kfood_health_val 경로 설정
kfood_health_val = './kfood_health_val'

# 이미지 파일 확장자 리스트
image_extensions = ['.jpg', '.jpeg', '.png', '.gif']

# 디렉토리 내의 각 파일에 대해 이미지 파일 개수 확인
for file_name in os.listdir(kfood_health_val):
    file_path = os.path.join(kfood_health_val, file_name)
    if os.path.isdir(file_path):
        image_count = 0
        for entry in os.listdir(file_path):
            entry_path = os.path.join(file_path, entry)
            if os.path.isfile(entry_path) and any(entry.lower().endswith(ext) for ext in image_extensions):
                # 이미지 파일 확장자를 가진 파일을 찾으면 개수를 누적
                image_count += 1
        print(f"파일명: {file_name}, 이미지 개수: {image_count}")
# Out:
# 파일명: 된장찌개, 이미지 개수: 109
# 파일명: 배추김치, 이미지 개수: 128
# 파일명: 갈비찜, 이미지 개수: 151
# 파일명: 김치국, 이미지 개수: 165
# 파일명: 모듬초밥, 이미지 개수: 161
# 파일명: 고등어, 이미지 개수: 137
# 파일명: 낚지볶음, 이미지 개수: 122
# 파일명: 가리비, 이미지 개수: 103
# 파일명: 떡국, 이미지 개수: 118
# 파일명: 돼지갈비찜, 이미지 개수: 107
# 파일명: 오리로스구이, 이미지 개수: 161
# 파일명: 순대, 이미지 개수: 87
# 파일명: 부대찌개, 이미지 개수: 215

# %%
# 한글 폰트 설정
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# 이미지 파일 확장자 리스트
image_extensions = ['.jpg', '.jpeg', '.png', '.gif']

def proc_img(filepath):
    labels = [str(filepath[i]).split("/")[-2] for i in range(len(filepath))]  # 이미지 파일 경로로부터 라벨 추출
    filepath = pd.Series(filepath, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')
    df = pd.concat([filepath, labels], axis=1) # 경로와 라벨 concatenate
    df = df.sample(frac=1, random_state=0).reset_index(drop=True) # index 재설정
    return df

# %%
# 이미지 파일 경로 리스트 생성
image_folder = './kfood_health_val'
image_files = [os.path.join(dp, f) for dp, dn, filenames in os.walk(image_folder) for f in filenames if os.path.splitext(f)[1].lower() in image_extensions]

# 데이터프레임 생성
df = proc_img(image_files)

# %%
# 라벨별 카운트 플롯 그리기
plt.subplots(figsize=(20, 10))
sns.countplot(data=df, x='Label')
plt.xticks(rotation=90)  # x 축 라벨을 90도 회전

# 한글 플롯 레이블에 대한 NFC 정규화
ax = plt.gca()
ax.set_xticklabels([unicodedata.normalize('NFC', label.get_text()) for label in ax.get_xticklabels()])
plt.title('kfood_health_val')

plt.show()

# %% [markdown]
# # Mission 3-1

# %% [markdown]
# ## load data

# %%
# 데이터 변환 정의
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # 이미지 크기 조정
    transforms.ToTensor(),           # 이미지를 PyTorch 텐서로 변환
    transforms.Normalize((0.6093853, 0.49013588, 0.3961599), (0.2530398, 0.25769088, 0.26764917))  # 이미지 정규화
])

transform_train = transforms.Compose([
    transforms.Resize((224, 224)),  # 이미지 크기 조정
    transforms.RandomRotation(180),  # 180도 랜덤 회전
    transforms.CenterCrop(220),  # 중앙 자르기
    transforms.ToTensor(),           # 이미지를 PyTorch 텐서로 변환
    transforms.Normalize((0.6093853, 0.49013588, 0.3961599), (0.2530398, 0.25769088, 0.26764917))  # 이미지 정규화
])

# 데이터셋 정의
dataset = ImageFolder(root='./kfood_health_train', transform=transform)
testset = ImageFolder(root='./kfood_health_val', transform=transform)

# %% [markdown]
# ## cross validation : kfood_health_train을 8:2로 나눠 train과 val로 정의

# %%
torch.manual_seed(1)

# 데이터를 Train과 Validation으로 분리
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# DataLoader 생성
batch_size = 64

# train_dataset에 transform_train을 적용
train_dataset.dataset.transform = transform_train

trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
valloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=4)

# %%
# 데이터 개수 확인
print(len(dataset))
print(len(train_dataset))
print(len(val_dataset))
print(len(trainloader))
print(len(testloader))
# Out:
# 14115
# 11292
# 2823
# 177
# 28

# %%
classes = dataset.classes
classes
# Out:
# ['가리비',
#  '갈비찜',
#  '고등어',
#  '김치국',
#  '낚지볶음',
#  '돼지갈비찜',
#  '된장찌개',
#  '떡국',
#  '모듬초밥',
#  '배추김치',
#  '부대찌개',
#  '순대',
#  '오리로스구이']

# %%
# 클래스 이름 가져오기
classes = dataset.classes
# unnormalize 함수 정의
def unnormalize(img):
    mean = (0.6093853, 0.49013588, 0.3961599)
    std = (0.2530398, 0.25769088, 0.26764917)
    img = img * torch.tensor(std).view(3, 1, 1) + torch.tensor(mean).view(3, 1, 1)
    return img
# imshow 함수 정의
def imshow(img):
    img = unnormalize(img)  # Unnormalize the image
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# 이미지 보여주기
imshow(torchvision.utils.make_grid(images))
# label 출력
print(' '.join(f'{classes[labels[j]]:5s}' for j in range(batch_size)))
# Out:
# 고등어 떡국 돼지갈비찜 고등어 오리로스구이 갈비찜 떡국 고등어 고등어 된장찌개 떡국 배추김치 낚지볶음 가리비 갈비찜 갈비찜 돼지갈비찜 부대찌개 된장찌개 낚지볶음 부대찌개 배추김치 가리비 갈비찜 가리비 된장찌개 오리로스구이 오리로스구이 오리로스구이 배추김치 고등어 낚지볶음 떡국 부대찌개 오리로스구이 돼지갈비찜 가리비 된장찌개 모듬초밥 모듬초밥 된장찌개 갈비찜 가리비 돼지갈비찜 배추김치 된장찌개 떡국 낚지볶음 갈비찜 가리비 고등어 오리로스구이 순대 부대찌개 갈비찜 돼지갈비찜 고등어 김치국 부대찌개 갈비찜 김치국 돼지갈비찜 갈비찜 오리로스구이

# %% [markdown]
# ## using resnet101 train

# %%
# resnet101 파라미터 무작위로 초기화하여 사용
resnet101 = models.resnet101(pretrained=False).to(device)

# fc layer 수정
resnet101.fc = nn.Linear(resnet101.fc.in_features, len(classes)).to(device)

# %%
state_dict_path='./mission2_1123.pt'
weights = torch.load(state_dict_path)

resnet101.fc = nn.Linear(resnet101.fc.in_features, 42)
# definc model : weights are randomly initiated
resnet101.load_state_dict(weights)
# Out:
# <All keys matched successfully>

# %%
# 기존 분류 레이어의 출력 피처 수 얻기
in_features = resnet101.fc.in_features

# 새로운 분류 레이어 정의 (출력 개수를 13로 변경)
new_classifier = nn.Linear(in_features, len(classes))

# 모델의 분류 레이어를 새로 정의한 레이어로 대체
resnet101.fc = new_classifier

'''
# freezing
for param in resnet101.parameters():
   param.requires_grad = False
# layer3부터 마지막 마지막 레이어까지만 가중치만 학습
for name, param in resnet101.named_parameters():
    if name.startswith('layer3') or name.startswith('layer4') or name.startswith('fc'):
    	param.requires_grad = True
'''

# 모델을 학습 모드로 설정
resnet101.train()

resnet101.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=13, bias=True)
# )

# %%
# 가중치 확인
for name, param in resnet101.named_parameters():
    print(f'{name}: requires_grad={param.requires_grad}')
# Out:
# conv1.weight: requires_grad=True
# bn1.weight: requires_grad=True
# bn1.bias: requires_grad=True
# layer1.0.conv1.weight: requires_grad=True
# layer1.0.bn1.weight: requires_grad=True
# layer1.0.bn1.bias: requires_grad=True
# layer1.0.conv2.weight: requires_grad=True
# layer1.0.bn2.weight: requires_grad=True
# layer1.0.bn2.bias: requires_grad=True
# layer1.0.conv3.weight: requires_grad=True
# layer1.0.bn3.weight: requires_grad=True
# layer1.0.bn3.bias: requires_grad=True
# layer1.0.downsample.0.weight: requires_grad=True
# layer1.0.downsample.1.weight: requires_grad=True
# layer1.0.downsample.1.bias: requires_grad=True
# layer1.1.conv1.weight: requires_grad=True
# layer1.1.bn1.weight: requires_grad=True
# layer1.1.bn1.bias: requires_grad=True
# layer1.1.conv2.weight: requires_grad=True
# layer1.1.bn2.weight: requires_grad=True
# layer1.1.bn2.bias: requires_grad=True
# layer1.1.conv3.weight: requires_grad=True
# layer1.1.bn3.weight: requires_grad=True
# layer1.1.bn3.bias: requires_grad=True
# layer1.2.conv1.weight: requires_grad=True
# layer1.2.bn1.weight: requires_grad=True
# layer1.2.bn1.bias: requires_grad=True
# layer1.2.conv2.weight: requires_grad=True
# layer1.2.bn2.weight: requires_grad=True
# layer1.2.bn2.bias: requires_grad=True
# layer1.2.conv3.weight: requires_grad=True
# layer1.2.bn3.weight: requires_grad=True
# layer1.2.bn3.bias: requires_grad=True
# layer2.0.conv1.weight: requires_grad=True
# layer2.0.bn1.weight: requires_grad=True
# layer2.0.bn1.bias: requires_grad=True
# layer2.0.conv2.weight: requires_grad=True
# layer2.0.bn2.weight: requires_grad=True
# layer2.0.bn2.bias: requires_grad=True
# layer2.0.conv3.weight: requires_grad=True
# layer2.0.bn3.weight: requires_grad=True
# layer2.0.bn3.bias: requires_grad=True
# layer2.0.downsample.0.weight: requires_grad=True
# layer2.0.downsample.1.weight: requires_grad=True
# layer2.0.downsample.1.bias: requires_grad=True
# layer2.1.conv1.weight: requires_grad=True
# layer2.1.bn1.weight: requires_grad=True
# layer2.1.bn1.bias: requires_grad=True
# layer2.1.conv2.weight: requires_grad=True
# layer2.1.bn2.weight: requires_grad=True
# layer2.1.bn2.bias: requires_grad=True
# layer2.1.conv3.weight: requires_grad=True
# layer2.1.bn3.weight: requires_grad=True
# layer2.1.bn3.bias: requires_grad=True
# layer2.2.conv1.weight: requires_grad=True
# layer2.2.bn1.weight: requires_grad=True
# layer2.2.bn1.bias: requires_grad=True
# layer2.2.conv2.weight: requires_grad=True
# layer2.2.bn2.weight: requires_grad=True
# layer2.2.bn2.bias: requires_grad=True
# layer2.2.conv3.weight: requires_grad=True
# layer2.2.bn3.weight: requires_grad=True
# layer2.2.bn3.bias: requires_grad=True
# layer2.3.conv1.weight: requires_grad=True
# layer2.3.bn1.weight: requires_grad=True
# layer2.3.bn1.bias: requires_grad=True
# layer2.3.conv2.weight: requires_grad=True
# layer2.3.bn2.weight: requires_grad=True
# layer2.3.bn2.bias: requires_grad=True
# layer2.3.conv3.weight: requires_grad=True
# layer2.3.bn3.weight: requires_grad=True
# layer2.3.bn3.bias: requires_grad=True
# layer3.0.conv1.weight: requires_grad=True
# layer3.0.bn1.weight: requires_grad=True
# layer3.0.bn1.bias: requires_grad=True
# layer3.0.conv2.weight: requires_grad=True
# layer3.0.bn2.weight: requires_grad=True
# layer3.0.bn2.bias: requires_grad=True
# layer3.0.conv3.weight: requires_grad=True
# layer3.0.bn3.weight: requires_grad=True
# layer3.0.bn3.bias: requires_grad=True
# layer3.0.downsample.0.weight: requires_grad=True
# layer3.0.downsample.1.weight: requires_grad=True
# layer3.0.downsample.1.bias: requires_grad=True
# layer3.1.conv1.weight: requires_grad=True
# layer3.1.bn1.weight: requires_grad=True
# layer3.1.bn1.bias: requires_grad=True
# layer3.1.conv2.weight: requires_grad=True
# layer3.1.bn2.weight: requires_grad=True
# layer3.1.bn2.bias: requires_grad=True
# layer3.1.conv3.weight: requires_grad=True
# layer3.1.bn3.weight: requires_grad=True
# layer3.1.bn3.bias: requires_grad=True
# layer3.2.conv1.weight: requires_grad=True
# layer3.2.bn1.weight: requires_grad=True
# layer3.2.bn1.bias: requires_grad=True
# layer3.2.conv2.weight: requires_grad=True
# layer3.2.bn2.weight: requires_grad=True
# layer3.2.bn2.bias: requires_grad=True
# layer3.2.conv3.weight: requires_grad=True
# layer3.2.bn3.weight: requires_grad=True
# layer3.2.bn3.bias: requires_grad=True
# layer3.3.conv1.weight: requires_grad=True
# layer3.3.bn1.weight: requires_grad=True
# layer3.3.bn1.bias: requires_grad=True
# layer3.3.conv2.weight: requires_grad=True
# layer3.3.bn2.weight: requires_grad=True
# layer3.3.bn2.bias: requires_grad=True
# layer3.3.conv3.weight: requires_grad=True
# layer3.3.bn3.weight: requires_grad=True
# layer3.3.bn3.bias: requires_grad=True
# layer3.4.conv1.weight: requires_grad=True
# layer3.4.bn1.weight: requires_grad=True
# layer3.4.bn1.bias: requires_grad=True
# layer3.4.conv2.weight: requires_grad=True
# layer3.4.bn2.weight: requires_grad=True
# layer3.4.bn2.bias: requires_grad=True
# layer3.4.conv3.weight: requires_grad=True
# layer3.4.bn3.weight: requires_grad=True
# layer3.4.bn3.bias: requires_grad=True
# layer3.5.conv1.weight: requires_grad=True
# layer3.5.bn1.weight: requires_grad=True
# layer3.5.bn1.bias: requires_grad=True
# layer3.5.conv2.weight: requires_grad=True
# layer3.5.bn2.weight: requires_grad=True
# layer3.5.bn2.bias: requires_grad=True
# layer3.5.conv3.weight: requires_grad=True
# layer3.5.bn3.weight: requires_grad=True
# layer3.5.bn3.bias: requires_grad=True
# layer3.6.conv1.weight: requires_grad=True
# layer3.6.bn1.weight: requires_grad=True
# layer3.6.bn1.bias: requires_grad=True
# layer3.6.conv2.weight: requires_grad=True
# layer3.6.bn2.weight: requires_grad=True
# layer3.6.bn2.bias: requires_grad=True
# layer3.6.conv3.weight: requires_grad=True
# layer3.6.bn3.weight: requires_grad=True
# layer3.6.bn3.bias: requires_grad=True
# layer3.7.conv1.weight: requires_grad=True
# layer3.7.bn1.weight: requires_grad=True
# layer3.7.bn1.bias: requires_grad=True
# layer3.7.conv2.weight: requires_grad=True
# layer3.7.bn2.weight: requires_grad=True
# layer3.7.bn2.bias: requires_grad=True
# layer3.7.conv3.weight: requires_grad=True
# layer3.7.bn3.weight: requires_grad=True
# layer3.7.bn3.bias: requires_grad=True
# layer3.8.conv1.weight: requires_grad=True
# layer3.8.bn1.weight: requires_grad=True
# layer3.8.bn1.bias: requires_grad=True
# layer3.8.conv2.weight: requires_grad=True
# layer3.8.bn2.weight: requires_grad=True
# layer3.8.bn2.bias: requires_grad=True
# layer3.8.conv3.weight: requires_grad=True
# layer3.8.bn3.weight: requires_grad=True
# layer3.8.bn3.bias: requires_grad=True
# layer3.9.conv1.weight: requires_grad=True
# layer3.9.bn1.weight: requires_grad=True
# layer3.9.bn1.bias: requires_grad=True
# layer3.9.conv2.weight: requires_grad=True
# layer3.9.bn2.weight: requires_grad=True
# layer3.9.bn2.bias: requires_grad=True
# layer3.9.conv3.weight: requires_grad=True
# layer3.9.bn3.weight: requires_grad=True
# layer3.9.bn3.bias: requires_grad=True
# layer3.10.conv1.weight: requires_grad=True
# layer3.10.bn1.weight: requires_grad=True
# layer3.10.bn1.bias: requires_grad=True
# layer3.10.conv2.weight: requires_grad=True
# layer3.10.bn2.weight: requires_grad=True
# layer3.10.bn2.bias: requires_grad=True
# layer3.10.conv3.weight: requires_grad=True
# layer3.10.bn3.weight: requires_grad=True
# layer3.10.bn3.bias: requires_grad=True
# layer3.11.conv1.weight: requires_grad=True
# layer3.11.bn1.weight: requires_grad=True
# layer3.11.bn1.bias: requires_grad=True
# layer3.11.conv2.weight: requires_grad=True
# layer3.11.bn2.weight: requires_grad=True
# layer3.11.bn2.bias: requires_grad=True
# layer3.11.conv3.weight: requires_grad=True
# layer3.11.bn3.weight: requires_grad=True
# layer3.11.bn3.bias: requires_grad=True
# layer3.12.conv1.weight: requires_grad=True
# layer3.12.bn1.weight: requires_grad=True
# layer3.12.bn1.bias: requires_grad=True
# layer3.12.conv2.weight: requires_grad=True
# layer3.12.bn2.weight: requires_grad=True
# layer3.12.bn2.bias: requires_grad=True
# layer3.12.conv3.weight: requires_grad=True
# layer3.12.bn3.weight: requires_grad=True
# layer3.12.bn3.bias: requires_grad=True
# layer3.13.conv1.weight: requires_grad=True
# layer3.13.bn1.weight: requires_grad=True
# layer3.13.bn1.bias: requires_grad=True
# layer3.13.conv2.weight: requires_grad=True
# layer3.13.bn2.weight: requires_grad=True
# layer3.13.bn2.bias: requires_grad=True
# layer3.13.conv3.weight: requires_grad=True
# layer3.13.bn3.weight: requires_grad=True
# layer3.13.bn3.bias: requires_grad=True
# layer3.14.conv1.weight: requires_grad=True
# layer3.14.bn1.weight: requires_grad=True
# layer3.14.bn1.bias: requires_grad=True
# layer3.14.conv2.weight: requires_grad=True
# layer3.14.bn2.weight: requires_grad=True
# layer3.14.bn2.bias: requires_grad=True
# layer3.14.conv3.weight: requires_grad=True
# layer3.14.bn3.weight: requires_grad=True
# layer3.14.bn3.bias: requires_grad=True
# layer3.15.conv1.weight: requires_grad=True
# layer3.15.bn1.weight: requires_grad=True
# layer3.15.bn1.bias: requires_grad=True
# layer3.15.conv2.weight: requires_grad=True
# layer3.15.bn2.weight: requires_grad=True
# layer3.15.bn2.bias: requires_grad=True
# layer3.15.conv3.weight: requires_grad=True
# layer3.15.bn3.weight: requires_grad=True
# layer3.15.bn3.bias: requires_grad=True
# layer3.16.conv1.weight: requires_grad=True
# layer3.16.bn1.weight: requires_grad=True
# layer3.16.bn1.bias: requires_grad=True
# layer3.16.conv2.weight: requires_grad=True
# layer3.16.bn2.weight: requires_grad=True
# layer3.16.bn2.bias: requires_grad=True
# layer3.16.conv3.weight: requires_grad=True
# layer3.16.bn3.weight: requires_grad=True
# layer3.16.bn3.bias: requires_grad=True
# layer3.17.conv1.weight: requires_grad=True
# layer3.17.bn1.weight: requires_grad=True
# layer3.17.bn1.bias: requires_grad=True
# layer3.17.conv2.weight: requires_grad=True
# layer3.17.bn2.weight: requires_grad=True
# layer3.17.bn2.bias: requires_grad=True
# layer3.17.conv3.weight: requires_grad=True
# layer3.17.bn3.weight: requires_grad=True
# layer3.17.bn3.bias: requires_grad=True
# layer3.18.conv1.weight: requires_grad=True
# layer3.18.bn1.weight: requires_grad=True
# layer3.18.bn1.bias: requires_grad=True
# layer3.18.conv2.weight: requires_grad=True
# layer3.18.bn2.weight: requires_grad=True
# layer3.18.bn2.bias: requires_grad=True
# layer3.18.conv3.weight: requires_grad=True
# layer3.18.bn3.weight: requires_grad=True
# layer3.18.bn3.bias: requires_grad=True
# layer3.19.conv1.weight: requires_grad=True
# layer3.19.bn1.weight: requires_grad=True
# layer3.19.bn1.bias: requires_grad=True
# layer3.19.conv2.weight: requires_grad=True
# layer3.19.bn2.weight: requires_grad=True
# layer3.19.bn2.bias: requires_grad=True
# layer3.19.conv3.weight: requires_grad=True
# layer3.19.bn3.weight: requires_grad=True
# layer3.19.bn3.bias: requires_grad=True
# layer3.20.conv1.weight: requires_grad=True
# layer3.20.bn1.weight: requires_grad=True
# layer3.20.bn1.bias: requires_grad=True
# layer3.20.conv2.weight: requires_grad=True
# layer3.20.bn2.weight: requires_grad=True
# layer3.20.bn2.bias: requires_grad=True
# layer3.20.conv3.weight: requires_grad=True
# layer3.20.bn3.weight: requires_grad=True
# layer3.20.bn3.bias: requires_grad=True
# layer3.21.conv1.weight: requires_grad=True
# layer3.21.bn1.weight: requires_grad=True
# layer3.21.bn1.bias: requires_grad=True
# layer3.21.conv2.weight: requires_grad=True
# layer3.21.bn2.weight: requires_grad=True
# layer3.21.bn2.bias: requires_grad=True
# layer3.21.conv3.weight: requires_grad=True
# layer3.21.bn3.weight: requires_grad=True
# layer3.21.bn3.bias: requires_grad=True
# layer3.22.conv1.weight: requires_grad=True
# layer3.22.bn1.weight: requires_grad=True
# layer3.22.bn1.bias: requires_grad=True
# layer3.22.conv2.weight: requires_grad=True
# layer3.22.bn2.weight: requires_grad=True
# layer3.22.bn2.bias: requires_grad=True
# layer3.22.conv3.weight: requires_grad=True
# layer3.22.bn3.weight: requires_grad=True
# layer3.22.bn3.bias: requires_grad=True
# layer4.0.conv1.weight: requires_grad=True
# layer4.0.bn1.weight: requires_grad=True
# layer4.0.bn1.bias: requires_grad=True
# layer4.0.conv2.weight: requires_grad=True
# layer4.0.bn2.weight: requires_grad=True
# layer4.0.bn2.bias: requires_grad=True
# layer4.0.conv3.weight: requires_grad=True
# layer4.0.bn3.weight: requires_grad=True
# layer4.0.bn3.bias: requires_grad=True
# layer4.0.downsample.0.weight: requires_grad=True
# layer4.0.downsample.1.weight: requires_grad=True
# layer4.0.downsample.1.bias: requires_grad=True
# layer4.1.conv1.weight: requires_grad=True
# layer4.1.bn1.weight: requires_grad=True
# layer4.1.bn1.bias: requires_grad=True
# layer4.1.conv2.weight: requires_grad=True
# layer4.1.bn2.weight: requires_grad=True
# layer4.1.bn2.bias: requires_grad=True
# layer4.1.conv3.weight: requires_grad=True
# layer4.1.bn3.weight: requires_grad=True
# layer4.1.bn3.bias: requires_grad=True
# layer4.2.conv1.weight: requires_grad=True
# layer4.2.bn1.weight: requires_grad=True
# layer4.2.bn1.bias: requires_grad=True
# layer4.2.conv2.weight: requires_grad=True
# layer4.2.bn2.weight: requires_grad=True
# layer4.2.bn2.bias: requires_grad=True
# layer4.2.conv3.weight: requires_grad=True
# layer4.2.bn3.weight: requires_grad=True
# layer4.2.bn3.bias: requires_grad=True
# fc.weight: requires_grad=True
# fc.bias: requires_grad=True

# %%
from torchsummary import summary
summary(resnet101, (3,224,224))
# 학습 가능한 파라미터 수
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-142          [-1, 256, 14, 14]             512
#             ReLU-143          [-1, 256, 14, 14]               0
#           Conv2d-144          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-145          [-1, 256, 14, 14]             512
#             ReLU-146          [-1, 256, 14, 14]               0
#           Conv2d-147         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-148         [-1, 1024, 14, 14]           2,048
#             ReLU-149         [-1, 1024, 14, 14]               0
#       Bottleneck-150         [-1, 1024, 14, 14]               0
#           Conv2d-151          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-152          [-1, 256, 14, 14]             512
#             ReLU-153          [-1, 256, 14, 14]               0
#           Conv2d-154          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-155          [-1, 256, 14, 14]             512
#             ReLU-156          [-1, 256, 14, 14]               0
#           Conv2d-157         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-158         [-1, 1024, 14, 14]           2,048
#             ReLU-159         [-1, 1024, 14, 14]               0
#       Bottleneck-160         [-1, 1024, 14, 14]               0
#           Conv2d-161          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-162          [-1, 256, 14, 14]             512
#             ReLU-163          [-1, 256, 14, 14]               0
#           Conv2d-164          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-165          [-1, 256, 14, 14]             512
#             ReLU-166          [-1, 256, 14, 14]               0
#           Conv2d-167         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-168         [-1, 1024, 14, 14]           2,048
#             ReLU-169         [-1, 1024, 14, 14]               0
#       Bottleneck-170         [-1, 1024, 14, 14]               0
#           Conv2d-171          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-172          [-1, 256, 14, 14]             512
#             ReLU-173          [-1, 256, 14, 14]               0
#           Conv2d-174          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-175          [-1, 256, 14, 14]             512
#             ReLU-176          [-1, 256, 14, 14]               0
#           Conv2d-177         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-178         [-1, 1024, 14, 14]           2,048
#             ReLU-179         [-1, 1024, 14, 14]               0
#       Bottleneck-180         [-1, 1024, 14, 14]               0
#           Conv2d-181          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-182          [-1, 256, 14, 14]             512
#             ReLU-183          [-1, 256, 14, 14]               0
#           Conv2d-184          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-185          [-1, 256, 14, 14]             512
#             ReLU-186          [-1, 256, 14, 14]               0
#           Conv2d-187         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-188         [-1, 1024, 14, 14]           2,048
#             ReLU-189         [-1, 1024, 14, 14]               0
#       Bottleneck-190         [-1, 1024, 14, 14]               0
#           Conv2d-191          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-192          [-1, 256, 14, 14]             512
#             ReLU-193          [-1, 256, 14, 14]               0
#           Conv2d-194          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-195          [-1, 256, 14, 14]             512
#             ReLU-196          [-1, 256, 14, 14]               0
#           Conv2d-197         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-198         [-1, 1024, 14, 14]           2,048
#             ReLU-199         [-1, 1024, 14, 14]               0
#       Bottleneck-200         [-1, 1024, 14, 14]               0
#           Conv2d-201          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-202          [-1, 256, 14, 14]             512
#             ReLU-203          [-1, 256, 14, 14]               0
#           Conv2d-204          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-205          [-1, 256, 14, 14]             512
#             ReLU-206          [-1, 256, 14, 14]               0
#           Conv2d-207         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-208         [-1, 1024, 14, 14]           2,048
#             ReLU-209         [-1, 1024, 14, 14]               0
#       Bottleneck-210         [-1, 1024, 14, 14]               0
#           Conv2d-211          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-212          [-1, 256, 14, 14]             512
#             ReLU-213          [-1, 256, 14, 14]               0
#           Conv2d-214          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-215          [-1, 256, 14, 14]             512
#             ReLU-216          [-1, 256, 14, 14]               0
#           Conv2d-217         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-218         [-1, 1024, 14, 14]           2,048
#             ReLU-219         [-1, 1024, 14, 14]               0
#       Bottleneck-220         [-1, 1024, 14, 14]               0
#           Conv2d-221          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-222          [-1, 256, 14, 14]             512
#             ReLU-223          [-1, 256, 14, 14]               0
#           Conv2d-224          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-225          [-1, 256, 14, 14]             512
#             ReLU-226          [-1, 256, 14, 14]               0
#           Conv2d-227         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-228         [-1, 1024, 14, 14]           2,048
#             ReLU-229         [-1, 1024, 14, 14]               0
#       Bottleneck-230         [-1, 1024, 14, 14]               0
#           Conv2d-231          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-232          [-1, 256, 14, 14]             512
#             ReLU-233          [-1, 256, 14, 14]               0
#           Conv2d-234          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-235          [-1, 256, 14, 14]             512
#             ReLU-236          [-1, 256, 14, 14]               0
#           Conv2d-237         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-238         [-1, 1024, 14, 14]           2,048
#             ReLU-239         [-1, 1024, 14, 14]               0
#       Bottleneck-240         [-1, 1024, 14, 14]               0
#           Conv2d-241          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-242          [-1, 256, 14, 14]             512
#             ReLU-243          [-1, 256, 14, 14]               0
#           Conv2d-244          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-245          [-1, 256, 14, 14]             512
#             ReLU-246          [-1, 256, 14, 14]               0
#           Conv2d-247         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-248         [-1, 1024, 14, 14]           2,048
#             ReLU-249         [-1, 1024, 14, 14]               0
#       Bottleneck-250         [-1, 1024, 14, 14]               0
#           Conv2d-251          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-252          [-1, 256, 14, 14]             512
#             ReLU-253          [-1, 256, 14, 14]               0
#           Conv2d-254          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-255          [-1, 256, 14, 14]             512
#             ReLU-256          [-1, 256, 14, 14]               0
#           Conv2d-257         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-258         [-1, 1024, 14, 14]           2,048
#             ReLU-259         [-1, 1024, 14, 14]               0
#       Bottleneck-260         [-1, 1024, 14, 14]               0
#           Conv2d-261          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-262          [-1, 256, 14, 14]             512
#             ReLU-263          [-1, 256, 14, 14]               0
#           Conv2d-264          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-265          [-1, 256, 14, 14]             512
#             ReLU-266          [-1, 256, 14, 14]               0
#           Conv2d-267         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-268         [-1, 1024, 14, 14]           2,048
#             ReLU-269         [-1, 1024, 14, 14]               0
#       Bottleneck-270         [-1, 1024, 14, 14]               0
#           Conv2d-271          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-272          [-1, 256, 14, 14]             512
#             ReLU-273          [-1, 256, 14, 14]               0
#           Conv2d-274          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-275          [-1, 256, 14, 14]             512
#             ReLU-276          [-1, 256, 14, 14]               0
#           Conv2d-277         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-278         [-1, 1024, 14, 14]           2,048
#             ReLU-279         [-1, 1024, 14, 14]               0
#       Bottleneck-280         [-1, 1024, 14, 14]               0
#           Conv2d-281          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-282          [-1, 256, 14, 14]             512
#             ReLU-283          [-1, 256, 14, 14]               0
#           Conv2d-284          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-285          [-1, 256, 14, 14]             512
#             ReLU-286          [-1, 256, 14, 14]               0
#           Conv2d-287         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-288         [-1, 1024, 14, 14]           2,048
#             ReLU-289         [-1, 1024, 14, 14]               0
#       Bottleneck-290         [-1, 1024, 14, 14]               0
#           Conv2d-291          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-292          [-1, 256, 14, 14]             512
#             ReLU-293          [-1, 256, 14, 14]               0
#           Conv2d-294          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-295          [-1, 256, 14, 14]             512
#             ReLU-296          [-1, 256, 14, 14]               0
#           Conv2d-297         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-298         [-1, 1024, 14, 14]           2,048
#             ReLU-299         [-1, 1024, 14, 14]               0
#       Bottleneck-300         [-1, 1024, 14, 14]               0
#           Conv2d-301          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-302          [-1, 256, 14, 14]             512
#             ReLU-303          [-1, 256, 14, 14]               0
#           Conv2d-304          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-305          [-1, 256, 14, 14]             512
#             ReLU-306          [-1, 256, 14, 14]               0
#           Conv2d-307         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-308         [-1, 1024, 14, 14]           2,048
#             ReLU-309         [-1, 1024, 14, 14]               0
#       Bottleneck-310         [-1, 1024, 14, 14]               0
#           Conv2d-311          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-312          [-1, 512, 14, 14]           1,024
#             ReLU-313          [-1, 512, 14, 14]               0
#           Conv2d-314            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-315            [-1, 512, 7, 7]           1,024
#             ReLU-316            [-1, 512, 7, 7]               0
#           Conv2d-317           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-318           [-1, 2048, 7, 7]           4,096
#           Conv2d-319           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-320           [-1, 2048, 7, 7]           4,096
#             ReLU-321           [-1, 2048, 7, 7]               0
#       Bottleneck-322           [-1, 2048, 7, 7]               0
#           Conv2d-323            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-324            [-1, 512, 7, 7]           1,024
#             ReLU-325            [-1, 512, 7, 7]               0
#           Conv2d-326            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-327            [-1, 512, 7, 7]           1,024
#             ReLU-328            [-1, 512, 7, 7]               0
#           Conv2d-329           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-330           [-1, 2048, 7, 7]           4,096
#             ReLU-331           [-1, 2048, 7, 7]               0
#       Bottleneck-332           [-1, 2048, 7, 7]               0
#           Conv2d-333            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-334            [-1, 512, 7, 7]           1,024
#             ReLU-335            [-1, 512, 7, 7]               0
#           Conv2d-336            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-337            [-1, 512, 7, 7]           1,024
#             ReLU-338            [-1, 512, 7, 7]               0
#           Conv2d-339           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-340           [-1, 2048, 7, 7]           4,096
#             ReLU-341           [-1, 2048, 7, 7]               0
#       Bottleneck-342           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-343           [-1, 2048, 1, 1]               0
#           Linear-344                   [-1, 13]          26,637
# ================================================================
# Total params: 42,526,797
# Trainable params: 42,526,797
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 429.72
# Params size (MB): 162.23
# Estimated Total Size (MB): 592.52
# ----------------------------------------------------------------

# %%
# 손실 함수 및 옵티마이저 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(resnet101.parameters(), lr=0.0005)

# %%
# 학습 중에 정확도와 손실 기록하기
train_accuracy_list = []
train_loss_list = []
validation_accuracy_list = []
validation_loss_list = []

val_accuracy_max=0
val_loss_min=99999999

# %%
# 학습 길이 50 epoch으로 설정하여 학습
for epoch in range(0, 50):

    # train
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device), data[1].to(device)
        optimizer.zero_grad()
        outputs = resnet101(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        # accuracy
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
        train_acc = 100 * correct_train / total_train

        # print every mini-batchs
        if i % 50 == 49 :
          print(f'[{epoch+1}, {i+1:5d}] train accuracy : {train_acc:.2f}% , train loss : {running_loss/2000:.3f}')
          running_loss = 0.0

    train_accs = 100 * correct_train / total_train
    train_accuracy_list.append(train_accs)
    train_loss_list.append(running_loss)

    # Validation accuracy & loss
    correct_validation = 0
    total_validation = 0
    validation_loss = 0.0

    with torch.no_grad():  # Disable gradient calculation for validation
        for i, data in enumerate(valloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            outputs = resnet101(inputs)
            loss = criterion(outputs, labels)
            validation_loss += loss.item()

            # Accuracy
            _, predicted = torch.max(outputs.data, 1)
            total_validation += labels.size(0)
            correct_validation += (predicted == labels).sum().item()

    validation_acc = 100 * correct_validation / total_validation
    print(f'epoch {epoch+1}: validation accuracy - {validation_acc:.2f}%, validation loss - {validation_loss/len(valloader):.3f}')

    validation_accuracy_list.append(validation_acc)
    validation_loss_list.append(validation_loss)

    # best model checkpoint에 저장
    if validation_acc > val_accuracy_max:
      val_accuracy_max = validation_acc
      torch.save(resnet101.state_dict(), './mission3_acc_101.pt')
    if validation_loss < val_loss_min:
      val_loss_min = validation_loss
      torch.save(resnet101.state_dict(), './mission3_loss_101.pt')

print('Finished Training')
# Out:
# [1,    50] train accuracy : 58.53% , train loss : 0.034
# [1,   100] train accuracy : 71.28% , train loss : 0.012
# [1,   150] train accuracy : 76.67% , train loss : 0.009
# epoch 1: validation accuracy - 88.38%, validation loss - 0.349
# [2,    50] train accuracy : 91.47% , train loss : 0.006
# [2,   100] train accuracy : 92.00% , train loss : 0.005
# [2,   150] train accuracy : 92.29% , train loss : 0.005
# epoch 2: validation accuracy - 92.70%, validation loss - 0.228
# [3,    50] train accuracy : 94.44% , train loss : 0.004
# [3,   100] train accuracy : 94.48% , train loss : 0.004
# [3,   150] train accuracy : 94.62% , train loss : 0.003
# epoch 3: validation accuracy - 94.51%, validation loss - 0.180
# [4,    50] train accuracy : 96.31% , train loss : 0.003
# [4,   100] train accuracy : 96.25% , train loss : 0.003
# [4,   150] train accuracy : 96.03% , train loss : 0.003
# epoch 4: validation accuracy - 94.72%, validation loss - 0.184
# [5,    50] train accuracy : 96.66% , train loss : 0.002
# [5,   100] train accuracy : 96.84% , train loss : 0.002
# [5,   150] train accuracy : 96.65% , train loss : 0.002
# epoch 5: validation accuracy - 95.47%, validation loss - 0.144
# [6,    50] train accuracy : 96.97% , train loss : 0.002
# [6,   100] train accuracy : 96.92% , train loss : 0.002
# [6,   150] train accuracy : 96.82% , train loss : 0.002
# epoch 6: validation accuracy - 95.47%, validation loss - 0.161
# [7,    50] train accuracy : 97.59% , train loss : 0.002
# [7,   100] train accuracy : 97.14% , train loss : 0.002
# [7,   150] train accuracy : 97.20% , train loss : 0.002
# epoch 7: validation accuracy - 95.61%, validation loss - 0.160
# [8,    50] train accuracy : 97.66% , train loss : 0.001
# [8,   100] train accuracy : 97.58% , train loss : 0.002
# [8,   150] train accuracy : 97.52% , train loss : 0.001
# epoch 8: validation accuracy - 95.64%, validation loss - 0.154
# [9,    50] train accuracy : 97.06% , train loss : 0.001
# [9,   100] train accuracy : 97.20% , train loss : 0.002
# [9,   150] train accuracy : 97.19% , train loss : 0.001
# epoch 9: validation accuracy - 96.17%, validation loss - 0.121
# [10,    50] train accuracy : 97.44% , train loss : 0.001
# [10,   100] train accuracy : 97.47% , train loss : 0.001
# [10,   150] train accuracy : 97.36% , train loss : 0.001
# epoch 10: validation accuracy - 95.93%, validation loss - 0.139
# [11,    50] train accuracy : 97.41% , train loss : 0.002
# [11,   100] train accuracy : 97.39% , train loss : 0.001
# [11,   150] train accuracy : 97.54% , train loss : 0.001
# epoch 11: validation accuracy - 96.17%, validation loss - 0.145
# [12,    50] train accuracy : 98.19% , train loss : 0.001
# [12,   100] train accuracy : 98.02% , train loss : 0.001
# [12,   150] train accuracy : 97.91% , train loss : 0.001
# epoch 12: validation accuracy - 96.10%, validation loss - 0.158
# [13,    50] train accuracy : 97.12% , train loss : 0.002
# [13,   100] train accuracy : 97.11% , train loss : 0.002
# [13,   150] train accuracy : 97.17% , train loss : 0.001
# epoch 13: validation accuracy - 96.21%, validation loss - 0.167
# [14,    50] train accuracy : 97.38% , train loss : 0.001
# [14,   100] train accuracy : 97.78% , train loss : 0.001
# [14,   150] train accuracy : 97.85% , train loss : 0.001
# epoch 14: validation accuracy - 96.56%, validation loss - 0.133
# [15,    50] train accuracy : 98.31% , train loss : 0.001
# [15,   100] train accuracy : 98.22% , train loss : 0.001
# [15,   150] train accuracy : 98.07% , train loss : 0.001
# epoch 15: validation accuracy - 95.54%, validation loss - 0.182
# [16,    50] train accuracy : 97.88% , train loss : 0.001
# [16,   100] train accuracy : 98.09% , train loss : 0.001
# [16,   150] train accuracy : 98.01% , train loss : 0.001
# epoch 16: validation accuracy - 96.17%, validation loss - 0.149
# [17,    50] train accuracy : 97.75% , train loss : 0.001
# [17,   100] train accuracy : 97.84% , train loss : 0.001
# [17,   150] train accuracy : 97.75% , train loss : 0.001
# epoch 17: validation accuracy - 96.10%, validation loss - 0.138
# [18,    50] train accuracy : 97.28% , train loss : 0.001
# [18,   100] train accuracy : 97.56% , train loss : 0.001
# [18,   150] train accuracy : 97.78% , train loss : 0.001
# epoch 18: validation accuracy - 96.56%, validation loss - 0.114
# [19,    50] train accuracy : 98.09% , train loss : 0.001
# [19,   100] train accuracy : 98.00% , train loss : 0.001
# [19,   150] train accuracy : 98.03% , train loss : 0.001
# epoch 19: validation accuracy - 96.67%, validation loss - 0.116
# [20,    50] train accuracy : 98.12% , train loss : 0.001
# [20,   100] train accuracy : 98.08% , train loss : 0.001
# [20,   150] train accuracy : 98.20% , train loss : 0.001
# epoch 20: validation accuracy - 96.00%, validation loss - 0.129
# [21,    50] train accuracy : 97.97% , train loss : 0.001
# [21,   100] train accuracy : 98.39% , train loss : 0.001
# [21,   150] train accuracy : 98.35% , train loss : 0.001
# epoch 21: validation accuracy - 96.32%, validation loss - 0.113
# [22,    50] train accuracy : 97.34% , train loss : 0.001
# [22,   100] train accuracy : 97.73% , train loss : 0.001
# [22,   150] train accuracy : 97.84% , train loss : 0.001
# epoch 22: validation accuracy - 96.39%, validation loss - 0.121
# [23,    50] train accuracy : 98.41% , train loss : 0.001
# [23,   100] train accuracy : 98.28% , train loss : 0.001
# [23,   150] train accuracy : 98.12% , train loss : 0.001
# epoch 23: validation accuracy - 96.49%, validation loss - 0.121
# [24,    50] train accuracy : 98.09% , train loss : 0.001
# [24,   100] train accuracy : 97.98% , train loss : 0.001
# [24,   150] train accuracy : 98.05% , train loss : 0.001
# epoch 24: validation accuracy - 96.74%, validation loss - 0.116
# [25,    50] train accuracy : 98.12% , train loss : 0.001
# [25,   100] train accuracy : 98.06% , train loss : 0.001
# [25,   150] train accuracy : 98.06% , train loss : 0.001
# epoch 25: validation accuracy - 96.35%, validation loss - 0.146
# [26,    50] train accuracy : 98.47% , train loss : 0.001
# [26,   100] train accuracy : 98.19% , train loss : 0.001
# [26,   150] train accuracy : 98.08% , train loss : 0.001
# epoch 26: validation accuracy - 96.42%, validation loss - 0.122
# [27,    50] train accuracy : 97.88% , train loss : 0.001
# [27,   100] train accuracy : 97.83% , train loss : 0.001
# [27,   150] train accuracy : 97.76% , train loss : 0.001
# epoch 27: validation accuracy - 96.81%, validation loss - 0.115
# [28,    50] train accuracy : 98.56% , train loss : 0.001
# [28,   100] train accuracy : 98.28% , train loss : 0.001
# [28,   150] train accuracy : 98.20% , train loss : 0.001
# epoch 28: validation accuracy - 97.06%, validation loss - 0.126
# [29,    50] train accuracy : 97.91% , train loss : 0.001
# [29,   100] train accuracy : 97.91% , train loss : 0.001
# [29,   150] train accuracy : 98.04% , train loss : 0.001
# epoch 29: validation accuracy - 96.56%, validation loss - 0.146
# [30,    50] train accuracy : 97.94% , train loss : 0.001
# [30,   100] train accuracy : 98.11% , train loss : 0.001
# [30,   150] train accuracy : 98.06% , train loss : 0.001
# epoch 30: validation accuracy - 96.28%, validation loss - 0.171
# [31,    50] train accuracy : 97.62% , train loss : 0.001
# [31,   100] train accuracy : 97.75% , train loss : 0.001
# [31,   150] train accuracy : 98.01% , train loss : 0.001
# epoch 31: validation accuracy - 96.67%, validation loss - 0.160
# [32,    50] train accuracy : 98.12% , train loss : 0.001
# [32,   100] train accuracy : 98.27% , train loss : 0.001
# [32,   150] train accuracy : 98.24% , train loss : 0.001
# epoch 32: validation accuracy - 96.10%, validation loss - 0.170
# [33,    50] train accuracy : 98.06% , train loss : 0.001
# [33,   100] train accuracy : 98.31% , train loss : 0.001
# [33,   150] train accuracy : 98.30% , train loss : 0.001
# epoch 33: validation accuracy - 96.78%, validation loss - 0.131
# [34,    50] train accuracy : 98.50% , train loss : 0.001
# [34,   100] train accuracy : 98.47% , train loss : 0.001
# [34,   150] train accuracy : 98.39% , train loss : 0.001
# epoch 34: validation accuracy - 96.56%, validation loss - 0.131
# [35,    50] train accuracy : 98.19% , train loss : 0.001
# [35,   100] train accuracy : 98.14% , train loss : 0.001
# [35,   150] train accuracy : 98.20% , train loss : 0.001
# epoch 35: validation accuracy - 96.17%, validation loss - 0.179
# [36,    50] train accuracy : 97.75% , train loss : 0.001
# [36,   100] train accuracy : 98.05% , train loss : 0.001
# [36,   150] train accuracy : 98.09% , train loss : 0.001
# epoch 36: validation accuracy - 96.32%, validation loss - 0.175
# [37,    50] train accuracy : 98.34% , train loss : 0.001
# [37,   100] train accuracy : 98.39% , train loss : 0.001
# [37,   150] train accuracy : 98.25% , train loss : 0.001
# epoch 37: validation accuracy - 96.21%, validation loss - 0.197
# [38,    50] train accuracy : 97.88% , train loss : 0.001
# [38,   100] train accuracy : 98.05% , train loss : 0.001
# [38,   150] train accuracy : 98.12% , train loss : 0.001
# epoch 38: validation accuracy - 96.85%, validation loss - 0.152
# [39,    50] train accuracy : 98.31% , train loss : 0.001
# [39,   100] train accuracy : 98.39% , train loss : 0.001
# [39,   150] train accuracy : 98.19% , train loss : 0.001
# epoch 39: validation accuracy - 96.17%, validation loss - 0.120
# [40,    50] train accuracy : 98.31% , train loss : 0.001
# [40,   100] train accuracy : 98.16% , train loss : 0.001
# [40,   150] train accuracy : 98.12% , train loss : 0.001
# epoch 40: validation accuracy - 96.67%, validation loss - 0.113
# [41,    50] train accuracy : 98.31% , train loss : 0.001
# [41,   100] train accuracy : 98.39% , train loss : 0.001
# [41,   150] train accuracy : 98.36% , train loss : 0.001
# epoch 41: validation accuracy - 97.10%, validation loss - 0.110
# [42,    50] train accuracy : 98.28% , train loss : 0.001
# [42,   100] train accuracy : 98.27% , train loss : 0.001
# [42,   150] train accuracy : 98.26% , train loss : 0.001
# epoch 42: validation accuracy - 96.78%, validation loss - 0.154
# [43,    50] train accuracy : 98.44% , train loss : 0.001
# [43,   100] train accuracy : 98.30% , train loss : 0.001
# [43,   150] train accuracy : 98.27% , train loss : 0.001
# epoch 43: validation accuracy - 95.93%, validation loss - 0.135
# [44,    50] train accuracy : 97.91% , train loss : 0.001
# [44,   100] train accuracy : 97.94% , train loss : 0.001
# [44,   150] train accuracy : 98.11% , train loss : 0.001
# epoch 44: validation accuracy - 96.88%, validation loss - 0.139
# [45,    50] train accuracy : 98.28% , train loss : 0.001
# [45,   100] train accuracy : 98.55% , train loss : 0.001
# [45,   150] train accuracy : 98.47% , train loss : 0.001
# epoch 45: validation accuracy - 97.02%, validation loss - 0.099
# [46,    50] train accuracy : 98.78% , train loss : 0.001
# [46,   100] train accuracy : 98.73% , train loss : 0.001
# [46,   150] train accuracy : 98.51% , train loss : 0.001
# epoch 46: validation accuracy - 96.53%, validation loss - 0.161
# [47,    50] train accuracy : 98.44% , train loss : 0.001
# [47,   100] train accuracy : 98.41% , train loss : 0.001
# [47,   150] train accuracy : 98.35% , train loss : 0.001
# epoch 47: validation accuracy - 96.67%, validation loss - 0.192
# [48,    50] train accuracy : 98.19% , train loss : 0.001
# [48,   100] train accuracy : 98.17% , train loss : 0.001
# [48,   150] train accuracy : 98.27% , train loss : 0.001
# epoch 48: validation accuracy - 96.56%, validation loss - 0.111
# [49,    50] train accuracy : 98.84% , train loss : 0.001
# [49,   100] train accuracy : 98.52% , train loss : 0.001
# [49,   150] train accuracy : 98.52% , train loss : 0.001
# epoch 49: validation accuracy - 97.20%, validation loss - 0.122
# [50,    50] train accuracy : 98.53% , train loss : 0.001
# [50,   100] train accuracy : 98.48% , train loss : 0.001
# [50,   150] train accuracy : 98.44% , train loss : 0.001
# epoch 50: validation accuracy - 96.99%, validation loss - 0.116
# Finished Training

# %%
PATH = './mission3_101.pt'
torch.save(resnet101.state_dict(),PATH) # 지정한 경로에 학습한 파라미터 저장

# %%
# 학습 중에 정확도와 손실 기록 시각화
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_accuracy_list, label='Training Accuracy')
plt.plot(validation_accuracy_list, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_loss_list, label='Training Loss')
plt.plot(validation_loss_list, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ## top1 accuracy

# %%
# valloader 이미지, 라벨 가져오기
dataiter = iter(valloader)
images, labels = next(dataiter)

# 클래스 이름 가져오기
classes = dataset.classes

# unnormalize함수 정의
def unnormalize(img):
    mean = (0.6093853, 0.49013588, 0.3961599)
    std = (0.2530398, 0.25769088, 0.26764917)
    img = img * torch.tensor(std).view(3, 1, 1) + torch.tensor(mean).view(3, 1, 1)
    return img

# inshow함수 정의
def imshow(img):
    img = unnormalize(img)  # Unnormalize the image
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# print images , GroundTruth: 실제 이미지 라벨
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join(f'{classes[labels[j]]:5s}' for j in range(batch_size)))
# Out:
# GroundTruth:  돼지갈비찜 가리비 돼지갈비찜 고등어 가리비 고등어 부대찌개 부대찌개 가리비 배추김치 순대 돼지갈비찜 김치국 부대찌개 부대찌개 된장찌개 돼지갈비찜 가리비 된장찌개 모듬초밥 가리비 고등어 된장찌개 된장찌개 가리비 배추김치 김치국 낚지볶음 갈비찜 순대 고등어 순대 고등어 가리비 부대찌개 고등어 돼지갈비찜 오리로스구이 모듬초밥 순대 고등어 떡국 된장찌개 순대 떡국 부대찌개 부대찌개 고등어 부대찌개 낚지볶음 배추김치 낚지볶음 돼지갈비찜 돼지갈비찜 갈비찜 배추김치 부대찌개 낚지볶음 된장찌개 김치국 가리비 김치국 모듬초밥 떡국

# %%
# 모델, 이미지 GPU 이동
resnet101 = resnet101.to(device)
images = images.to(device)

# 이미지 입력, 출력 계산
outputs = resnet101(images)

# %%
_, predicted = torch.max(outputs, 1) # 각 class의 확률이 가장 높은 것만 출력

# 예측 label 출력
print('Predicted: ', ' '.join(f'{classes[predicted[j]]:5s}' for j in range(batch_size)))
# Out:
# Predicted:  돼지갈비찜 가리비 돼지갈비찜 고등어 가리비 고등어 부대찌개 부대찌개 가리비 배추김치 순대 돼지갈비찜 된장찌개 부대찌개 부대찌개 된장찌개 돼지갈비찜 가리비 된장찌개 모듬초밥 가리비 고등어 된장찌개 된장찌개 가리비 배추김치 김치국 부대찌개 갈비찜 순대 고등어 순대 고등어 가리비 부대찌개 고등어 돼지갈비찜 오리로스구이 모듬초밥 순대 고등어 떡국 된장찌개 순대 떡국 부대찌개 부대찌개 고등어 부대찌개 낚지볶음 배추김치 낚지볶음 돼지갈비찜 돼지갈비찜 갈비찜 배추김치 부대찌개 낚지볶음 된장찌개 김치국 가리비 김치국 모듬초밥 떡국

# %%
# Validation accuracy 출력
val_correct = 0
val_total = 0

with torch.no_grad():
    for data in valloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = resnet101(images)
        _, predicted = torch.max(outputs.data, 1)
        val_total += labels.size(0)
        val_correct += (predicted == labels).sum().item()

print(f'Validation Accuracy: {100 * val_correct // val_total} %')
# Out:
# Validation Accuracy: 96 %

# %%
#각 클래스 중에서 어떤 클래스를 잘 맞췄는지, 어떤 클래스를 잘 못맞췄는지 확인
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in valloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = resnet101(images.to(device))
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: 가리비 is 94.1 %
# Accuracy for class: 갈비찜 is 89.4 %
# Accuracy for class: 고등어 is 98.7 %
# Accuracy for class: 김치국 is 99.6 %
# Accuracy for class: 낚지볶음 is 98.1 %
# Accuracy for class: 돼지갈비찜 is 84.3 %
# Accuracy for class: 된장찌개 is 98.6 %
# Accuracy for class: 떡국 is 100.0 %
# Accuracy for class: 모듬초밥 is 97.1 %
# Accuracy for class: 배추김치 is 100.0 %
# Accuracy for class: 부대찌개 is 99.3 %
# Accuracy for class: 순대 is 98.9 %
# Accuracy for class: 오리로스구이 is 99.5 %

# %% [markdown]
# ## validation 채점 : kfood_health_val 데이터 사용해서 정확도 측정

# %%
# 채점시 사용되는 코드
@torch.no_grad()
def validate_epoch(model: nn.Module, data_loader: DataLoader, device: torch.device):
    ''' data_loader provides inputs and GTs.
        model receives input images from data_loader and produces logits.
        returns the accuracy of model in percent.
    '''
    model.eval()
    accuracies = []
    for images, labels in tqdm(data_loader, total=len(data_loader), mininterval=1, desc='measuring accuracy'):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        pred = torch.argmax(logits, dim=1)

        accuracies.append(pred == labels)

    accuracy = torch.concat(accuracies).float().mean() * 100
    return accuracy.item()

# %%
validate_epoch(resnet101,testloader,device)
# Out:
# measuring accuracy:   0%|          | 0/28 [00:00<?, ?it/s]
# 97.22222137451172

# %% [markdown]
# # checkpoint loader

# %%
# 저장했던 mission3.pt 불러오기
PATH = './mission3_loss_101.pt'
resnet101 = models.resnet101(weights=None)
optimizer = optim.Adam(resnet101.parameters(), lr=0.001)

num_classes = 13
resnet101.fc = nn.Linear(resnet101.fc.in_features, num_classes)

checkpoint = torch.load(PATH)
resnet101.load_state_dict(checkpoint)

# 평가모드
resnet101.eval()

resnet101 = resnet101.to(device)

# %%
# 채점시 사용되는 코드
@torch.no_grad()
def validate_epoch(model: nn.Module, data_loader: DataLoader, device: torch.device):
    ''' data_loader provides inputs and GTs.
        model receives input images from data_loader and produces logits.
        returns the accuracy of model in percent.
    '''
    model.eval()
    accuracies = []
    for images, labels in tqdm(data_loader, total=len(data_loader), mininterval=1, desc='measuring accuracy'):
        images = images.to(device)
        labels = labels.to(device)

        logits = model(images)
        pred = torch.argmax(logits, dim=1)

        accuracies.append(pred == labels)

    accuracy = torch.concat(accuracies).float().mean() * 100
    return accuracy.item()

# %%
validate_epoch(resnet101,testloader,device)
# Out:
# measuring accuracy:   0%|          | 0/28 [00:00<?, ?it/s]
# 97.61904907226562
